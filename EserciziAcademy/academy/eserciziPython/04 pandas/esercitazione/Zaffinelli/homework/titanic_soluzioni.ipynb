# %% [markdown]
# Import pandas

# %%
import pandas as pd

# %% [markdown]
# Read the `titanic3.xls` file and set 'name' as the index

# %%
titanic = pd.read_excel('titanic3.xls', index_col='name')
titanic.head()
# Out:
#                                                  pclass  survived     sex  \
# name
# Allen, Miss. Elisabeth Walton                         1         1  female
# Allison, Master. Hudson Trevor                        1         1    male
# Allison, Miss. Helen Loraine                          1         0  female
# Allison, Mr. Hudson Joshua Creighton                  1         0    male
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)       1         0  female
#
#                                                      age  sibsp  parch  \
# name
# Allen, Miss. Elisabeth Walton                    29.0000      0      0
# Allison, Master. Hudson Trevor                    0.9167      1      2
# Allison, Miss. Helen Loraine                      2.0000      1      2
# Allison, Mr. Hudson Joshua Creighton             30.0000      1      2
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  25.0000      1      2
#
#                                                  ticket      fare    cabin  \
# name
# Allen, Miss. Elisabeth Walton                     24160  211.3375       B5
# Allison, Master. Hudson Trevor                   113781  151.5500  C22 C26
# Allison, Miss. Helen Loraine                     113781  151.5500  C22 C26
# Allison, Mr. Hudson Joshua Creighton             113781  151.5500  C22 C26
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  113781  151.5500  C22 C26
#
#                                                 embarked boat   body  \
# name
# Allen, Miss. Elisabeth Walton                          S    2    NaN
# Allison, Master. Hudson Trevor                         S   11    NaN
# Allison, Miss. Helen Loraine                           S  NaN    NaN
# Allison, Mr. Hudson Joshua Creighton                   S  NaN  135.0
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)        S  NaN    NaN
#
#                                                                        home.dest
# name
# Allen, Miss. Elisabeth Walton                                       St Louis, MO
# Allison, Master. Hudson Trevor                   Montreal, PQ / Chesterville, ON
# Allison, Miss. Helen Loraine                     Montreal, PQ / Chesterville, ON
# Allison, Mr. Hudson Joshua Creighton             Montreal, PQ / Chesterville, ON
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  Montreal, PQ / Chesterville, ON

# %% [markdown]
# Drop the following columns: `['home.dest', 'embarked', 'sibsp', 'parch']`

# %%
titanic.drop(columns=['home.dest', 'embarked', 'sibsp', 'parch'], inplace=True)
titanic.head()
# Out:
#                                                  pclass  survived     sex  \
# name
# Allen, Miss. Elisabeth Walton                         1         1  female
# Allison, Master. Hudson Trevor                        1         1    male
# Allison, Miss. Helen Loraine                          1         0  female
# Allison, Mr. Hudson Joshua Creighton                  1         0    male
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)       1         0  female
#
#                                                      age  ticket      fare  \
# name
# Allen, Miss. Elisabeth Walton                    29.0000   24160  211.3375
# Allison, Master. Hudson Trevor                    0.9167  113781  151.5500
# Allison, Miss. Helen Loraine                      2.0000  113781  151.5500
# Allison, Mr. Hudson Joshua Creighton             30.0000  113781  151.5500
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  25.0000  113781  151.5500
#
#                                                    cabin boat   body
# name
# Allen, Miss. Elisabeth Walton                         B5    2    NaN
# Allison, Master. Hudson Trevor                   C22 C26   11    NaN
# Allison, Miss. Helen Loraine                     C22 C26  NaN    NaN
# Allison, Mr. Hudson Joshua Creighton             C22 C26  NaN  135.0
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  C22 C26  NaN    NaN

# %% [markdown]
# Filter out all the passengers which did not survive.

# %%
titanic = titanic[titanic['survived'] ==1]
titanic
# Out:
#                                                  pclass  survived     sex  \
# name
# Allen, Miss. Elisabeth Walton                         1         1  female
# Allison, Master. Hudson Trevor                        1         1    male
# Anderson, Mr. Harry                                   1         1    male
# Andrews, Miss. Kornelia Theodosia                     1         1  female
# Appleton, Mrs. Edward Dale (Charlotte Lamson)         1         1  female
# ...                                                 ...       ...     ...
# Turkula, Mrs. (Hedwig)                                3         1  female
# Vartanian, Mr. David                                  3         1    male
# Whabee, Mrs. George Joseph (Shawneene Abi-Saab)       3         1  female
# Wilkes, Mrs. James (Ellen Needs)                      3         1  female
# Yasbeck, Mrs. Antoni (Selini Alexander)               3         1  female
#
#                                                      age  ticket      fare  \
# name
# Allen, Miss. Elisabeth Walton                    29.0000   24160  211.3375
# Allison, Master. Hudson Trevor                    0.9167  113781  151.5500
# Anderson, Mr. Harry                              48.0000   19952   26.5500
# Andrews, Miss. Kornelia Theodosia                63.0000   13502   77.9583
# Appleton, Mrs. Edward Dale (Charlotte Lamson)    53.0000   11769   51.4792
# ...                                                  ...     ...       ...
# Turkula, Mrs. (Hedwig)                           63.0000    4134    9.5875
# Vartanian, Mr. David                             22.0000    2658    7.2250
# Whabee, Mrs. George Joseph (Shawneene Abi-Saab)  38.0000    2688    7.2292
# Wilkes, Mrs. James (Ellen Needs)                 47.0000  363272    7.0000
# Yasbeck, Mrs. Antoni (Selini Alexander)          15.0000    2659   14.4542
#
#                                                    cabin   boat  body
# name
# Allen, Miss. Elisabeth Walton                         B5      2   NaN
# Allison, Master. Hudson Trevor                   C22 C26     11   NaN
# Anderson, Mr. Harry                                  E12      3   NaN
# Andrews, Miss. Kornelia Theodosia                     D7     10   NaN
# Appleton, Mrs. Edward Dale (Charlotte Lamson)       C101      D   NaN
# ...                                                  ...    ...   ...
# Turkula, Mrs. (Hedwig)                               NaN     15   NaN
# Vartanian, Mr. David                                 NaN  13 15   NaN
# Whabee, Mrs. George Joseph (Shawneene Abi-Saab)      NaN      C   NaN
# Wilkes, Mrs. James (Ellen Needs)                     NaN    NaN   NaN
# Yasbeck, Mrs. Antoni (Selini Alexander)              NaN    NaN   NaN
#
# [500 rows x 9 columns]

# %% [markdown]
# Considering that the **body** column is only used for passengers who did not survive, drop that column, and then do the same thing for the **survived** column.

# %%
titanic.drop(columns= ['survived','body'],inplace=True)

# %% [markdown]
# What is the max **fare** in **3rd class**?

# %%
titanic[titanic['pclass']==3]['fare'].max()
# Out:
# np.float64(56.4958)

# %% [markdown]
# Rename the index name of 'name' to 'Passenger'

# %%
titanic.index.name= 'Passenger'
titanic.head()
# Out:
#                                                pclass     sex      age  \
# Passenger
# Allen, Miss. Elisabeth Walton                       1  female  29.0000
# Allison, Master. Hudson Trevor                      1    male   0.9167
# Anderson, Mr. Harry                                 1    male  48.0000
# Andrews, Miss. Kornelia Theodosia                   1  female  63.0000
# Appleton, Mrs. Edward Dale (Charlotte Lamson)       1  female  53.0000
#
#                                                ticket      fare    cabin boat
# Passenger
# Allen, Miss. Elisabeth Walton                   24160  211.3375       B5    2
# Allison, Master. Hudson Trevor                 113781  151.5500  C22 C26   11
# Anderson, Mr. Harry                             19952   26.5500      E12    3
# Andrews, Miss. Kornelia Theodosia               13502   77.9583       D7   10
# Appleton, Mrs. Edward Dale (Charlotte Lamson)   11769   51.4792     C101    D

# %% [markdown]
# **BONUS**
#
# Create a new column that's called "Free Coffee", insert 1 if a passenger is either in 1st or 2nd class, otherwise insert 0

# %%
titanic['Free Coffee'] = 0
titanic.loc[titanic['pclass'].isin([1,2]), 'Free Coffee'] =1
titanic.head()
# Out:
#                                                pclass     sex      age  \
# Passenger
# Allen, Miss. Elisabeth Walton                       1  female  29.0000
# Allison, Master. Hudson Trevor                      1    male   0.9167
# Anderson, Mr. Harry                                 1    male  48.0000
# Andrews, Miss. Kornelia Theodosia                   1  female  63.0000
# Appleton, Mrs. Edward Dale (Charlotte Lamson)       1  female  53.0000
#
#                                                ticket      fare    cabin boat  \
# Passenger
# Allen, Miss. Elisabeth Walton                   24160  211.3375       B5    2
# Allison, Master. Hudson Trevor                 113781  151.5500  C22 C26   11
# Anderson, Mr. Harry                             19952   26.5500      E12    3
# Andrews, Miss. Kornelia Theodosia               13502   77.9583       D7   10
# Appleton, Mrs. Edward Dale (Charlotte Lamson)   11769   51.4792     C101    D
#
#                                                Free Coffee
# Passenger
# Allen, Miss. Elisabeth Walton                            1
# Allison, Master. Hudson Trevor                           1
# Anderson, Mr. Harry                                      1
# Andrews, Miss. Kornelia Theodosia                        1
# Appleton, Mrs. Edward Dale (Charlotte Lamson)            1

# %% [markdown]
# Use value_counts() to verify that 3rd class doesn't get any free coffee

# %%
#titanic.loc[:, ['pclass','Free Coffee']].value_counts() 
titanic[['pclass', 'Free Coffee']].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 #titanic.loc[:, ['pclass','Free Coffee']].value_counts()
# ----> 2 titanic[['pclass', 'Free Coffee']].value_counts()
#
# NameError: name 'titanic' is not defined
