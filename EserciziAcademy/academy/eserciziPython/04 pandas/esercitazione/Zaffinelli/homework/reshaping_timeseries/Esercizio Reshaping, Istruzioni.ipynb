# %% [markdown]
# # Esercizio Reshaping, Istruzioni

# %% [markdown]
# Popolazione (in migliaia) nelle regioni d'Italia per titolo di studio: http://dati.istat.it/Index.aspx?QueryId=26176

# %%
import pandas as pd

df = pd.read_csv("studio.csv", encoding='latin1')

df
# Out:
#     Territorio   Sesso  Classe di età  \
# 0     Piemonte  maschi  15 anni e più
# 1     Piemonte  maschi  15 anni e più
# 2     Piemonte  maschi  15 anni e più
# 3     Piemonte  maschi  15 anni e più
# 4     Piemonte  maschi  15 anni e più
# ..         ...     ...            ...
# 787   Sardegna  totale  15 anni e più
# 788   Sardegna  totale  15 anni e più
# 789   Sardegna  totale  15 anni e più
# 790   Sardegna  totale  15 anni e più
# 791   Sardegna  totale  15 anni e più
#
#                                       Titolo di studio  TIME     Value
# 0    licenza di scuola elementare, nessun titolo di...  2018   226.200
# 1    licenza di scuola elementare, nessun titolo di...  2019   211.578
# 2                              licenza di scuola media  2018   656.363
# 3                              licenza di scuola media  2019   651.879
# 4           diploma 2-3 anni (qualifica professionale)  2018   147.788
# ..                                                 ...   ...       ...
# ...

# %%
df.Territorio.value_counts() # 20 regioni piu' provincia autonoma di Bolzano e Trento
# Out:
# Provincia Autonoma Trento             36
# Piemonte                              36
# Provincia Autonoma Bolzano / Bozen    36
# Friuli-Venezia Giulia                 36
# Liguria                               36
# Basilicata                            36
# Umbria                                36
# Veneto                                36
# Marche                                36
# Lazio                                 36
# Puglia                                36
# Lombardia                             36
# Toscana                               36
# Molise                                36
# Trentino Alto Adige / Südtirol        36
# Calabria                              36
# Emilia-Romagna                        36
# Sicilia                               36
# Campania                              36
# Sardegna                              36
# Valle d'Aosta / Vallée d'Aoste        36
# Abruzzo                               36
# Name: Territorio, dtype: int64

# %%
df.Sesso.value_counts()
# Out:
# totale     264
# femmine    264
# maschi     264
# Name: Sesso, dtype: int64

# %%
df["Classe di età"].value_counts()
# Out:
# 15 anni e più    792
# Name: Classe di età, dtype: int64

# %%
df.TIME.value_counts() # tipo int
# Out:
# 2019    396
# 2018    396
# Name: TIME, dtype: int64

# %%
df["Titolo di studio"].value_counts()
# Out:
# totale                                                   132
# diploma 4-5 anni (maturità)                              132
# licenza di scuola media                                  132
# diploma 2-3 anni (qualifica professionale)               132
# laurea e post-laurea                                     132
# licenza di scuola elementare, nessun titolo di studio    132
# Name: Titolo di studio, dtype: int64

# %% [markdown]
# #####  Elimina (in maniera permanente) dal dataframe tutte le righe che contengono sotto la colonna "Sesso" la stringa "totale"

# %% [markdown]
# #####  Elimina (in maniera permanente) dal dataframe tutte le righe che contengono sotto la colonna "Titolo di Studio" la stringa "totale"

# %% [markdown]
# ##### 2 - Visualizza il seguente output
#
# - devi ottenere il numero totale di persone per ogni regione per anno

# %%
# Out:
#                                             Value
# Territorio                         TIME
# Abruzzo                            2018  1144.803
#                                    2019  1141.831
# Basilicata                         2018   495.227
#                                    2019   492.004
# Calabria                           2018  1685.481
#                                    2019  1678.471
# Campania                           2018  4948.019
#                                    2019  4936.763
# Emilia-Romagna                     2018  3832.478
#                                    2019  3841.515
# Friuli-Venezia Giulia              2018  1058.068
#                                    2019  1057.567
# Lazio                              2018  5059.488
#                                    2019  5052.360
# Liguria                            2018  1367.161
#                                    2019  1361.733
# Lombardia                          2018  8591.619
# ...

# %% [markdown]
# ##### Visualizza il seguente output
# - simile a prima ma devi distinguere la somma totale di persone tra maschi e femmine

# %%
# Out:
# Sesso                                     femmine    maschi
# Territorio                         TIME
# Abruzzo                            2018   591.799   553.004
#                                    2019   589.937   551.894
# Basilicata                         2018   254.096   241.131
#                                    2019   252.515   239.489
# Calabria                           2018   867.238   818.243
#                                    2019   863.039   815.432
# Campania                           2018  2559.907  2388.112
#                                    2019  2555.248  2381.515
# Emilia-Romagna                     2018  1988.410  1844.068
#                                    2019  1991.602  1849.913
# Friuli-Venezia Giulia              2018   548.003   510.065
#                                    2019   547.274   510.293
# Lazio                              2018  2639.612  2419.876
#                                    2019  2637.677  2414.683
# ...

# %% [markdown]
# ##### ottieni il seguente output
# - il numero totale di persone nel 2018 e 2019, per ogni regione distinguendo tra maschi e femmine

# %%
# Out:
# Sesso                                femmine              maschi
# TIME                                    2018      2019      2018      2019
# Territorio
# Abruzzo                             1183.597  1179.873  1106.008  1103.788
# Basilicata                           508.192   505.031   482.263   478.978
# Calabria                            1734.477  1726.077  1636.486  1630.864
# Campania                            5119.814  5110.496  4776.224  4763.031
# Emilia-Romagna                      3976.820  3983.203  3688.134  3699.826
# Friuli-Venezia Giulia               1096.007  1094.548  1020.129  1020.586
# Lazio                               5279.225  5275.354  4839.751  4829.367
# Liguria                             1440.090  1433.674  1294.232  1289.793
# Lombardia                           8841.189  8868.350  8342.048  8378.938
# Marche                              1376.477  1372.365  1276.356  1273.988
# ...

# %% [markdown]
# #### ottieni il seguente output
# - Numero totale di persone per titolo di studio per regione negli anni 2018 e 2019

# %%
# Out:
# TIME                                                                     2018  \
# Titolo di studio                   diploma 2-3 anni (qualifica professionale)
# Territorio
# Abruzzo                                                                40.687
# Basilicata                                                             17.559
# Calabria                                                               33.025
# Campania                                                              128.247
# Emilia-Romagna                                                        285.886
# Friuli-Venezia Giulia                                                  95.105
# Lazio                                                                 144.283
# Liguria                                                                85.083
# Lombardia                                                             721.819
# Marche                                                                 62.275
# ...

# %% [markdown]
# #### Visualizza il seguente output
#
# - simile a prima ma in pratica con gli "assi invertiti"
# - fai attenzione che e' richiesto di visualizzare solo l'anno 2018

# %%
# Out:
# Territorio                                               Abruzzo           \
# Sesso                                                    femmine   maschi
# Titolo di studio                                   TIME
# diploma 2-3 anni (qualifica professionale)         2018   16.432   24.255
# diploma 4-5 anni (maturità)                        2018  203.683  202.849
# laurea e post-laurea                               2018   95.939   74.590
# licenza di scuola elementare, nessun titolo di ... 2018  122.622   72.309
# licenza di scuola media                            2018  153.123  179.001
#
# Territorio                                              Basilicata          \
# Sesso                                                      femmine  maschi
# Titolo di studio                                   TIME
# diploma 2-3 anni (qualifica professionale)         2018      7.335  10.224
# diploma 4-5 anni (maturità)                        2018     83.718  87.081
# ...
