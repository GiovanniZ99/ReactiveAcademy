# %% [markdown]
# ## Esercizio: Series, Istruzioni

# %% [markdown]
#  importa pandas con il suo alias "pd"

# %%
import pandas as pd

# %% [markdown]
# leggi il file "fifa20.csv" come una **series** selezionando solo le colonne "player" e "height_cm" e utilizza la colonna "player" come indice. Assegna la series ad una variabile che chiameremo "altezza"

# %%
altezza = pd.read_csv('fifa20.csv', usecols=['player', 'height_cm',], index_col = 'player')
altezza.squeeze()
# Out:
# player
# L. Messi             170
# Cristiano Ronaldo    187
# Neymar Jr            175
# J. Oblak             188
# E. Hazard            175
#                     ...
# Shao Shuai           186
# Xiao Mingjie         177
# Zhang Wei            186
# Wang Haijian         185
# Pan Ximing           182
# Name: height_cm, Length: 18278, dtype: int64

# %% [markdown]
#  Visualizza i primi 10 giocatori della series appena creata

# %%
altezza.head(10)
# Out:
#                    height_cm
# player
# L. Messi                 170
# Cristiano Ronaldo        187
# Neymar Jr                175
# J. Oblak                 188
# E. Hazard                175
# K. De Bruyne             181
# M. ter Stegen            187
# V. van Dijk              193
# L. Modrić                172
# M. Salah                 175

# %% [markdown]
# Crea una nuova series formata solo dalle prime 500 righe di "altezza" e chiamala top500

# %% [markdown]
# Chi e' il giocatore  piu' alto?

# %% [markdown]
# e quello piu' basso?

# %% [markdown]
# quanto e' alto il giocatore piu' alto? e il piu' basso?

# %% [markdown]
# altezza media dei top500 giocatori?

# %% [markdown]
# quanto e' alto "M. Salah" ?

# %% [markdown]
# salva la series top500 in un file csv con nome "top500"
